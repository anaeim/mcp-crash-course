# %% [markdown]
# **Q**. what in mcp inspector?
# an open source project by the anthropic team, which came up with the Model Context protocol, which is going to help us and enable us to troubleshoot, debug and trace and to see what actually happens in our MCP server.
#
# ![image.png](attachment:image.png)
