# %% [markdown]
# Video 10: how to integrate mcp with desktop claude?
#
# You clone a prebuilt mcp server from github and integrate it with builtin clients like cursor or antropic.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q. What do you update in claude_desktop_config.json? <br>
# So now we want to populate it with information that is going to help cloud understand , what is the name, where our servers are located and how to run them (i.e., what is the command).
#
# ![image.png](attachment:image.png)
